# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extracting Data

# %%
Data=pd.read_csv("be_propertiesTest.csv")
Data
# Out:
#             id              locality     p_type                    sub_type  \
# 0     20278524                  gent      other                     offices
# 1     20311402              mechelen      other  mixed-use-building-offices
# 2     20311809             antwerpen      other                     offices
# 3     11393966             antwerpen      other                     offices
# 4     20301468            anderlecht      other                     offices
# ...        ...                   ...        ...                         ...
# 6296  11491599               brussel  apartment                   apartment
# 6297  20078257          knokke-heist  apartment                   apartment
# 6298  20134748               ixelles  apartment                ground-floor
# 6299  20178038         heist-aan-zee  apartment                   apartment
# 6300  20105789  woluwe-saint-lambert  apartment                ground-floor
#
#          price  bedrooms  living_area  equip_kitchen  furnished  open_fire  \
# 0     860000.0       NaN        450.0              0          0          0
# 1     995000.0       NaN        419.0              1          0          0
# 2     215000.0       NaN         40.0              0          0          0
# 3     149000.0       NaN         67.0              1          0          0
# 4     520000.0       NaN        525.0              0          0          0
# ...        ...       ...          ...            ...        ...        ...
# 6296  570000.0       3.0        151.0              0          0          0
# 6297  595000.0       2.0         62.0              0          0          0
# 6298  598000.0       3.0        123.0              0          0          0
# 6299  598000.0       2.0         96.0              1          0          0
# 6300  599000.0       3.0        155.0              1          0          0
#
#       terrace  terrace_area  garden  garden_area  land_surface  \
# 0           0           NaN       0          NaN           450
# 1           0           NaN       0          NaN           419
# 2           0           NaN       0          NaN            40
# 3           1          10.0       1         10.0            87
# 4           0           NaN       0          NaN           525
# ...       ...           ...     ...          ...           ...
# 6296        0           NaN       0          NaN           151
# 6297        0           NaN       0          NaN            62
# 6298        1          12.0       1        100.0           235
# 6299        1           4.0       0          NaN           100
# 6300        1          45.0       0          NaN           200
#
#       surface of the plot           state  facades  swim_pool
# 0                     450            Good        4          0
# 1                       0   To be done up        2          0
# 2                       0          As new        2          0
# 3                      73  Just renovated        3          0
# 4                     525            Good        4          0
# ...                   ...             ...      ...        ...
# 6296                    0  Just renovated        2          0
# 6297                    0  Just renovated        0          0
# 6298                    0     To renovate        2          1
# 6299                    0             NaN        0          0
# 6300                    0            Good        3          1
#
# [6301 rows x 19 columns]

# %%
Data = Data.replace('', np.nan).fillna(value=np.nan)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6301 entries, 0 to 6300
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6301 non-null   int64
#  1   locality             6301 non-null   object
#  2   p_type               6301 non-null   object
#  3   sub_type             6301 non-null   object
#  4   price                6291 non-null   float64
#  5   bedrooms             4126 non-null   float64
#  6   living_area          4867 non-null   float64
#  7   equip_kitchen        6301 non-null   int64
#  8   furnished            6301 non-null   int64
#  9   open_fire            6301 non-null   int64
#  10  terrace              6301 non-null   int64
#  11  terrace_area         2611 non-null   float64
#  12  garden               6301 non-null   int64
#  13  garden_area          580 non-null    float64
#  14  land_surface         6301 non-null   int64
#  15  surface of the plot  6301 non-null   int64
#  16  state                3380 non-null   object
#  17  facades              6301 non-null   int64
#  18  swim_pool            6301 non-null   int64
# dtypes: float64(5), int64(10), object(4)
# memory usage: 935.4+ KB

# %%
Data['locality'] = Data['locality'].str.replace(r'[^a-zA-Z\s]', '', regex=True).str.title()

# %%
Data.locality
# Out:
# 0                     Gent
# 1                 Mechelen
# 2                Antwerpen
# 3                Antwerpen
# 4               Anderlecht
#                ...
# 6296               Brussel
# 6297           Knokkeheist
# 6298               Ixelles
# 6299           Heistaanzee
# 6300    Woluwesaintlambert
# Name: locality, Length: 6301, dtype: object

# %%
Data.columns
# Out:
# Index(['id', 'locality', 'p_type', 'sub_type', 'price', 'bedrooms',
#        'living_area', 'equip_kitchen', 'furnished', 'open_fire', 'terrace',
#        'terrace_area', 'garden', 'garden_area', 'land_surface',
#        'surface of the plot', 'state', 'facades', 'swim_pool'],
#       dtype='object')

# %%
cols=['Id', 'Locality', 'Type', 'SubType', 'Price', 'Bedrooms',
       'Living_Area', 'Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire', 'Terrace',
       'Terrace_Area', 'Garden', 'Garden_Area', 'Land_Surface',
       'Surface of the plot', 'State', 'Facades', 'Swim_pool']

# %%
Data.columns=cols
Data
# Out:
#             Id            Locality       Type                     SubType  \
# 0     20278524                Gent      other                     offices
# 1     20311402            Mechelen      other  mixed-use-building-offices
# 2     20311809           Antwerpen      other                     offices
# 3     11393966           Antwerpen      other                     offices
# 4     20301468          Anderlecht      other                     offices
# ...        ...                 ...        ...                         ...
# 6296  11491599             Brussel  apartment                   apartment
# 6297  20078257         Knokkeheist  apartment                   apartment
# 6298  20134748             Ixelles  apartment                ground-floor
# 6299  20178038         Heistaanzee  apartment                   apartment
# 6300  20105789  Woluwesaintlambert  apartment                ground-floor
#
#          Price  Bedrooms  Living_Area  Is_Equiped_Kitchen  Is_Furnished  \
# 0     860000.0       NaN        450.0                   0             0
# 1     995000.0       NaN        419.0                   1             0
# 2     215000.0       NaN         40.0                   0             0
# 3     149000.0       NaN         67.0                   1             0
# 4     520000.0       NaN        525.0                   0             0
# ...        ...       ...          ...                 ...           ...
# 6296  570000.0       3.0        151.0                   0             0
# 6297  595000.0       2.0         62.0                   0             0
# 6298  598000.0       3.0        123.0                   0             0
# 6299  598000.0       2.0         96.0                   1             0
# 6300  599000.0       3.0        155.0                   1             0
#
#       Is_Open_Fire  Terrace  Terrace_Area  Garden  Garden_Area  Land_Surface  \
# 0                0        0           NaN       0          NaN           450
# 1                0        0           NaN       0          NaN           419
# 2                0        0           NaN       0          NaN            40
# 3                0        1          10.0       1         10.0            87
# 4                0        0           NaN       0          NaN           525
# ...            ...      ...           ...     ...          ...           ...
# 6296             0        0           NaN       0          NaN           151
# 6297             0        0           NaN       0          NaN            62
# 6298             0        1          12.0       1        100.0           235
# 6299             0        1           4.0       0          NaN           100
# 6300             0        1          45.0       0          NaN           200
#
#       Surface of the plot           State  Facades  Swim_pool
# 0                     450            Good        4          0
# 1                       0   To be done up        2          0
# 2                       0          As new        2          0
# 3                      73  Just renovated        3          0
# 4                     525            Good        4          0
# ...                   ...             ...      ...        ...
# 6296                    0  Just renovated        2          0
# 6297                    0  Just renovated        0          0
# 6298                    0     To renovate        2          1
# 6299                    0             NaN        0          0
# 6300                    0            Good        3          1
#
# [6301 rows x 19 columns]

# %%
Data.Type=Data.Type.str.title()

# %%
Data
# Out:
#             Id            Locality       Type                     SubType  \
# 0     20278524                Gent      Other                     offices
# 1     20311402            Mechelen      Other  mixed-use-building-offices
# 2     20311809           Antwerpen      Other                     offices
# 3     11393966           Antwerpen      Other                     offices
# 4     20301468          Anderlecht      Other                     offices
# ...        ...                 ...        ...                         ...
# 6296  11491599             Brussel  Apartment                   apartment
# 6297  20078257         Knokkeheist  Apartment                   apartment
# 6298  20134748             Ixelles  Apartment                ground-floor
# 6299  20178038         Heistaanzee  Apartment                   apartment
# 6300  20105789  Woluwesaintlambert  Apartment                ground-floor
#
#          Price  Bedrooms  Living_Area  Is_Equiped_Kitchen  Is_Furnished  \
# 0     860000.0       NaN        450.0                   0             0
# 1     995000.0       NaN        419.0                   1             0
# 2     215000.0       NaN         40.0                   0             0
# 3     149000.0       NaN         67.0                   1             0
# 4     520000.0       NaN        525.0                   0             0
# ...        ...       ...          ...                 ...           ...
# 6296  570000.0       3.0        151.0                   0             0
# 6297  595000.0       2.0         62.0                   0             0
# 6298  598000.0       3.0        123.0                   0             0
# 6299  598000.0       2.0         96.0                   1             0
# 6300  599000.0       3.0        155.0                   1             0
#
#       Is_Open_Fire  Terrace  Terrace_Area  Garden  Garden_Area  Land_Surface  \
# 0                0        0           NaN       0          NaN           450
# 1                0        0           NaN       0          NaN           419
# 2                0        0           NaN       0          NaN            40
# 3                0        1          10.0       1         10.0            87
# 4                0        0           NaN       0          NaN           525
# ...            ...      ...           ...     ...          ...           ...
# 6296             0        0           NaN       0          NaN           151
# 6297             0        0           NaN       0          NaN            62
# 6298             0        1          12.0       1        100.0           235
# 6299             0        1           4.0       0          NaN           100
# 6300             0        1          45.0       0          NaN           200
#
#       Surface of the plot           State  Facades  Swim_pool
# 0                     450            Good        4          0
# 1                       0   To be done up        2          0
# 2                       0          As new        2          0
# 3                      73  Just renovated        3          0
# 4                     525            Good        4          0
# ...                   ...             ...      ...        ...
# 6296                    0  Just renovated        2          0
# 6297                    0  Just renovated        0          0
# 6298                    0     To renovate        2          1
# 6299                    0             NaN        0          0
# 6300                    0            Good        3          1
#
# [6301 rows x 19 columns]

# %%
Data.SubType.value_counts(ascending=False)
# Out:
# SubType
# apartment                     2578
# house                          880
# covered-parking-space          708
# offices                        559
# lock-up-garage                 179
# outdoor-parking-space          176
# ground-floor                   169
# penthouse                      161
# office-block                   157
# flat-studio                    117
# duplex                         107
# lock-up-parking                100
# mixed-use-building-offices      77
# villa                           62
# building                        60
# apartment-block                 38
# service-flat                    33
# mixed-use-building              26
# commercial-premises             19
# exceptional-property            14
# loft                            14
# country-cottage                 11
# mansion                         10
# triplex                         10
# town-house                       9
# business                         7
# kot                              5
# bungalow                         4
# farmhouse                        3
# manor-house                      3
# building-land                    2
# chalet                           2
# large-town-house                 1
# Name: count, dtype: int64

# %%
Data.Price=
