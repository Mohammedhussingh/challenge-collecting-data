# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extracting Data

# %%
Data=pd.read_csv("be_properties.csv")
Data
# Out:
#              id          locality     p_type                    sub_type  \
# 0      20278524              gent      other                     offices
# 1      20311402          mechelen      other  mixed-use-building-offices
# 2      20311809         antwerpen      other                     offices
# 3      11393966         antwerpen      other                     offices
# 4      20301468        anderlecht      other                     offices
# ...         ...               ...        ...                         ...
# 13730  20289024           berchem  apartment                   apartment
# 13731  20289023           hoboken  apartment                   apartment
# 13732  20289022             hamme      house                       house
# 13733  20289018             lasne      house                       house
# 13734  20289017  trooz%20fraipont      other             country-cottage
#
#           price  bedrooms  living_area  equip_kitchen  furnished  open_fire  \
# ...

# %% [markdown]
# ### Filling Empty Cells

# %%
Data = Data.replace('', np.nan).fillna(value=np.nan)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13735 entries, 0 to 13734
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   13735 non-null  int64
#  1   locality             13735 non-null  object
#  2   p_type               13735 non-null  object
#  3   sub_type             13735 non-null  object
#  4   price                13707 non-null  float64
#  5   bedrooms             11383 non-null  float64
#  6   living_area          11966 non-null  float64
#  7   equip_kitchen        13735 non-null  int64
#  8   furnished            13735 non-null  int64
#  9   open_fire            13735 non-null  int64
#  10  terrace              13735 non-null  int64
#  11  terrace_area         5555 non-null   float64
#  12  garden               13735 non-null  int64
#  13  garden_area          2494 non-null   float64
#  14  land_surface         13735 non-null  int64
# ...

# %% [markdown]
# ### Name cleaning

# %%
Data['locality'] = Data['locality'].str.replace(r'[^a-zA-Z\s]', '', regex=True).str.title()

# %%
Data.locality
# Out:
# 0                 Gent
# 1             Mechelen
# 2            Antwerpen
# 3            Antwerpen
# 4           Anderlecht
#              ...
# 13730          Berchem
# 13731          Hoboken
# 13732            Hamme
# 13733            Lasne
# 13734    Troozfraipont
# Name: locality, Length: 13735, dtype: object

# %%
Data.columns
# Out:
# Index(['id', 'locality', 'p_type', 'sub_type', 'price', 'bedrooms',
#        'living_area', 'equip_kitchen', 'furnished', 'open_fire', 'terrace',
#        'terrace_area', 'garden', 'garden_area', 'land_surface',
#        'surface of the plot', 'state', 'facades', 'swim_pool'],
#       dtype='object')

# %% [markdown]
# ### Columns name fixing

# %%
cols=['Id', 'Locality', 'Type', 'SubType', 'Price', 'Bedrooms',
       'Living_Area', 'Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire', 'Terrace',
       'Terrace_Area', 'Garden', 'Garden_Area', 'Land_Surface',
       'Surface of the plot', 'State', 'Facades', 'Swim_pool']

# %%
Data.columns=cols
Data
# Out:
#              Id       Locality       Type                     SubType  \
# 0      20278524           Gent      other                     offices
# 1      20311402       Mechelen      other  mixed-use-building-offices
# 2      20311809      Antwerpen      other                     offices
# 3      11393966      Antwerpen      other                     offices
# 4      20301468     Anderlecht      other                     offices
# ...         ...            ...        ...                         ...
# 13730  20289024        Berchem  apartment                   apartment
# 13731  20289023        Hoboken  apartment                   apartment
# 13732  20289022          Hamme      house                       house
# 13733  20289018          Lasne      house                       house
# 13734  20289017  Troozfraipont      other             country-cottage
#
#           Price  Bedrooms  Living_Area  Is_Equiped_Kitchen  Is_Furnished  \
# ...

# %%
Data.Type=Data.Type.str.title()

# %%
Data
# Out:
#              Id       Locality       Type                     SubType  \
# 0      20278524           Gent      Other                     offices
# 1      20311402       Mechelen      Other  mixed-use-building-offices
# 2      20311809      Antwerpen      Other                     offices
# 3      11393966      Antwerpen      Other                     offices
# 4      20301468     Anderlecht      Other                     offices
# ...         ...            ...        ...                         ...
# 13730  20289024        Berchem  Apartment                   apartment
# 13731  20289023        Hoboken  Apartment                   apartment
# 13732  20289022          Hamme      House                       house
# 13733  20289018          Lasne      House                       house
# 13734  20289017  Troozfraipont      Other             country-cottage
#
#           Price  Bedrooms  Living_Area  Is_Equiped_Kitchen  Is_Furnished  \
# ...

# %%
Data.SubType.value_counts(ascending=False)
# Out:
# SubType
# apartment                     4680
# house                         4432
# covered-parking-space          706
# offices                        554
# villa                          491
# ground-floor                   302
# penthouse                      279
# apartment-block                263
# duplex                         238
# flat-studio                    235
# mixed-use-building             217
# lock-up-garage                 178
# outdoor-parking-space          176
# office-block                   156
# lock-up-parking                100
# exceptional-property           100
# mansion                         84
# town-house                      80
# mixed-use-building-offices      77
# building                        59
# bungalow                        58
# service-flat                    52
# country-cottage                 47
# loft                            46
# triplex                         23
# farmhouse                       21
# ...

# %% [markdown]
# ### Price type adjustment and fill null

# %%
Data.Price=Data.Price.astype(int)

# %%
Data['Price'] = Data['Price'].fillna(0)  # Replace NaN with 0
Data['Price'].replace([np.inf, -np.inf], 0, inplace=True)  # Replace Inf/-Inf with 0

# Convert to integer
Data['Price'] = Data['Price'].astype(int)

# %%
Data
# Out:
#              Id       Locality       Type                     SubType   Price  \
# 0      20278524           Gent      Other                     offices  860000
# 1      20311402       Mechelen      Other  mixed-use-building-offices  995000
# 2      20311809      Antwerpen      Other                     offices  215000
# 3      11393966      Antwerpen      Other                     offices  149000
# 4      20301468     Anderlecht      Other                     offices  520000
# ...         ...            ...        ...                         ...     ...
# 13730  20289024        Berchem  Apartment                   apartment  499000
# 13731  20289023        Hoboken  Apartment                   apartment  195000
# 13732  20289022          Hamme      House                       house  420000
# 13733  20289018          Lasne      House                       house  575000
# 13734  20289017  Troozfraipont      Other             country-cottage  299000
#
# ...

# %%
Data.Bedrooms.fillna(0).astype(int)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 13730    2
# 13731    3
# 13732    2
# 13733    3
# 13734    5
# Name: Bedrooms, Length: 13735, dtype: int64

# %% [markdown]
# ### Booleans adjustments

# %%
Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace']]=Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace']].astype(bool)

# %%
Data.Bedrooms= Data.Bedrooms.fillna(0).astype(int)

# %%
Data
# Out:
#              Id       Locality       Type                     SubType   Price  \
# 0      20278524           Gent      Other                     offices  860000
# 1      20311402       Mechelen      Other  mixed-use-building-offices  995000
# 2      20311809      Antwerpen      Other                     offices  215000
# 3      11393966      Antwerpen      Other                     offices  149000
# 4      20301468     Anderlecht      Other                     offices  520000
# ...         ...            ...        ...                         ...     ...
# 13730  20289024        Berchem  Apartment                   apartment  499000
# 13731  20289023        Hoboken  Apartment                   apartment  195000
# 13732  20289022          Hamme      House                       house  420000
# 13733  20289018          Lasne      House                       house  575000
# 13734  20289017  Troozfraipont      Other             country-cottage  299000
#
# ...

# %%
Edited_Data= Data

# %%
Edited_Data
# Out:
#              Id       Locality       Type                     SubType   Price  \
# 0      20278524           Gent      Other                     offices  860000
# 1      20311402       Mechelen      Other  mixed-use-building-offices  995000
# 2      20311809      Antwerpen      Other                     offices  215000
# 3      11393966      Antwerpen      Other                     offices  149000
# 4      20301468     Anderlecht      Other                     offices  520000
# ...         ...            ...        ...                         ...     ...
# 13730  20289024        Berchem  Apartment                   apartment  499000
# 13731  20289023        Hoboken  Apartment                   apartment  195000
# 13732  20289022          Hamme      House                       house  420000
# 13733  20289018          Lasne      House                       house  575000
# 13734  20289017  Troozfraipont      Other             country-cottage  299000
#
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6301 entries, 0 to 6300
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   6301 non-null   int64
#  1   Locality             6301 non-null   object
#  2   Type                 6301 non-null   object
#  3   SubType              6301 non-null   object
#  4   Price                6301 non-null   int64
#  5   Bedrooms             6301 non-null   int64
#  6   Living_Area          6301 non-null   float64
#  7   Is_Equiped_Kitchen   6301 non-null   bool
#  8   Is_Furnished         6301 non-null   bool
#  9   Is_Open_Fire         6301 non-null   bool
#  10  Terrace              6301 non-null   bool
#  11  Terrace_Area         6301 non-null   float64
#  12  Garden               6301 non-null   bool
#  13  Garden_Area          6301 non-null   float64
#  14  Land_Surface         6301 non-null   int64
# ...

# %%
Data.Terrace_Area=Data.Terrace_Area.fillna(0)
Data['Locality'] = Data['Locality'].astype(str)
Data['Type'] = Data['Type'].astype(str)
Data['SubType'] = Data['SubType'].astype(str)

# %%
Data.Garden_Area=Data.Garden_Area.fillna(0)

# %%
Data.State=Data.State.fillna("Not Known")

# %%
Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace','Garden','Swim_pool']]=Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace','Garden','Swim_pool']]=Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace','Garden','Swim_pool']]=Data[['Is_Equiped_Kitchen', 'Is_Furnished', 'Is_Open_Fire','Terrace','Garden','Swim_pool']].astype(bool)

# %%
nan_count_per_column = Data.isna().sum()
nan_count_per_column
# Out:
# Id                     0
# Locality               0
# Type                   0
# SubType                0
# Price                  0
# Bedrooms               0
# Living_Area            0
# Is_Equiped_Kitchen     0
# Is_Furnished           0
# Is_Open_Fire           0
# Terrace                0
# Terrace_Area           0
# Garden                 0
# Garden_Area            0
# Land_Surface           0
# Surface of the plot    0
# State                  0
# Facades                0
# Swim_pool              0
# dtype: int64

# %%
Data.Living_Area =Data.Living_Area.fillna(0)

# %% [markdown]
# ### Adding sales type (all what we  collected private)

# %%
Data["Sale_Type"]="Private"

# %%
Data.Terrace_Area=Data.Terrace_Area.fillna(0)
Data
# Out:
#              Id       Locality       Type                     SubType   Price  \
# 0      20278524           Gent      Other                     offices  860000
# 1      20311402       Mechelen      Other  mixed-use-building-offices  995000
# 2      20311809      Antwerpen      Other                     offices  215000
# 3      11393966      Antwerpen      Other                     offices  149000
# 4      20301468     Anderlecht      Other                     offices  520000
# ...         ...            ...        ...                         ...     ...
# 13730  20289024        Berchem  Apartment                   apartment  499000
# 13731  20289023        Hoboken  Apartment                   apartment  195000
# 13732  20289022          Hamme      House                       house  420000
# 13733  20289018          Lasne      House                       house  575000
# 13734  20289017  Troozfraipont      Other             country-cottage  299000
#
# ...

# %%
Data.to_csv("Training_Data.csv",index=True)
